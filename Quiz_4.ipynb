# %% [markdown]
# <a href="https://colab.research.google.com/github/olivocdz-cmd/Programacion1/blob/main/Quiz_4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **Python permite cargar y crear objetos de archivos dados, tambien permite crear archivos y editar archivos dados**

# %%
# crear y escribir un archivo de texto
with open("archivo.txt", "w") as f:
    f.write("Hola, este es un archivo de texto.\n")
    f.write("segunda línea.\n")

# %%
with open("archivo.txt", "r") as f:
    print(f.read())
# Out:
# Hola, este es un archivo de texto.
# segunda línea.

# %%
from google.colab import files
files.download("archivo.txt")

# %%
#abrir es modo append para editar un archivo ya existente
with open("archivo.txt", "a") as f:
  f.write("\esta es una nueva linea añadida.")
# Out:
# <>:3: SyntaxWarning: invalid escape sequence '\e'
# <>:3: SyntaxWarning: invalid escape sequence '\e'
# /tmp/ipykernel_3341/1725265810.py:3: SyntaxWarning: invalid escape sequence '\e'
#   f.write("\esta es una nueva linea añadida.")

# %%
with open("archivo.txt", "r") as f:
    print(f.read())
# Out:
# Hola, este es un archivo de texto.
# segunda línea.
# \esta es una nueva linea añadida.

# %%
with open("archivo.txt", "w") as f:
    f.write("Hola, mi nombre es Carlos días.\n")
    f.write("Me gusta salir hacer senderismo.\n")

# %%
with open("archivo.txt", "r") as f:
    print(f.read())
# Out:
# Hola, mi nombre es Carlos días.
# Me gusta salir hacer senderismo.

# %%
from google.colab import files
files.download("archivo.txt")

# %%
with open("archivo.txt", "a") as f:
  f.write("\ Aunque a veces me da algo de pereza salir de casa.")
# Out:
# <>:2: SyntaxWarning: invalid escape sequence '\ '
# <>:2: SyntaxWarning: invalid escape sequence '\ '
# /tmp/ipykernel_3341/1044638036.py:2: SyntaxWarning: invalid escape sequence '\ '
#   f.write("\ Aunque a veces me da algo de pereza salir de casa.")

# %%
with open("archivo.txt", "r") as f:
    print(f.read())
# Out:
# Hola, mi nombre es Carlos días.
# Me gusta salir hacer senderismo.
# \ Aunque a veces me da algo de pereza salir de casa.

# %%
from google.colab import files
files.download("archivo.txt")

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-101493d7-5453-46fe-9f99-f5de41c0bc3e" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-101493d7-5453-46fe-9f99-f5de41c0bc3e">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
with open ("archivo (1).txt", "w") as f:
  f.write("Este archivo fue completamente modificado.\n")
  f.write("nueva linea 1.\n")
  f.write("nueva linea 2.\n")

# %%
with open ("archivo (1).txt", "r") as f:
  print(f.read())
# Out:
# Este archivo fue completamente modificado.
# nueva linea 1.
# nueva linea 2.

# %%
from google.colab import files
files.download("archivo (1).txt")

# %%
import csv
datos = [["Nombre", "Edad", "Ciudad"],
         ["Alice", 25, "Nueva York"],
         ["Bob", 30, "Los Angeles"],
         ["Charlie", 35, "Chicago"]
]
with open("datos.csv", "w", newline="") as f:
    writer = csv.writer(f)
    writer.writerows(datos)

# %%
files.download("datos.csv")

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
ruta = "/content/drive/MyDrive/datos.csv"
import shutil
shutil.copy("/content/datos.csv", ruta) #"datos.csv": archivo origen en colab
# Out:
# '/content/drive/MyDrive/datos.csv'

# %%
with open(ruta, "r") as f:
  print(f.read())
# Out:
# Nombre,Edad,Ciudad
# Alice,25,Nueva York
# Bob,30,Los Angeles
# Charlie,35,Chicago

# %%
with open(ruta, "r") as f:
  data = list(csv.reader(f))
#agrega una nueva fila
data.append(["david", "28", "armenia"]) #ajustar segun columnas existent
data
# Out:
# [['Nombre', 'Edad', 'Ciudad'],
#  ['Alice', '25', 'Nueva York'],
#  ['Bob', '30', 'Los Angeles'],
#  ['Charlie', '35', 'Chicago'],
#  ['david', '28', 'armenia']]

# %%
import pandas as pd
data1 = pd.DataFrame(data)
data1
# Out:
#          0     1            2
# 0   Nombre  Edad       Ciudad
# 1    Alice    25   Nueva York
# 2      Bob    30  Los Angeles
# 3  Charlie    35      Chicago
# 4    david    28      armenia

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# The 'Ciudad' column is at index 2 in the DataFrame 'data1'
ciudad_counts = data1[2].value_counts()

plt.figure(figsize=(10, 6))
sns.barplot(x=ciudad_counts.index, y=ciudad_counts.values)
plt.title('Distribución de Ciudades')
plt.xlabel('Ciudad')
plt.ylabel('Cantidad')
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %%
import csv

ruta = "/content/drive/MyDrive/datos.csv"

# Leer
with open(ruta, "r") as f:
    data = list(csv.reader(f))

# Mostrar antes
print("ANTES:")
print(data)

# Agregar fila
data.append(["Diego", "28", "Armenia"])

# Guardar
with open(ruta, "w", newline="") as f:
    writer = csv.writer(f)
    writer.writerows(data)

# Mostrar después
print("\nDESPUÉS:")
with open(ruta, "r") as f:
    print(f.read())
# Out:
# ANTES:
# [['Nombre', 'Edad', 'Ciudad'], ['Alice', '25', 'Nueva York'], ['Bob', '30', 'Los Angeles'], ['Charlie', '35', 'Chicago']]
#
# DESPUÉS:
# Nombre,Edad,Ciudad
# Alice,25,Nueva York
# Bob,30,Los Angeles
# Charlie,35,Chicago
# Diego,28,Armenia

# %%
import os
os.listdir("/content/drive/MyDrive")
# Out:
# ['Colab Notebooks',
#  'Carlos Diaz - Kodland',
#  'contrato_58860_11775071.pdf',
#  'contrato_58860_11775071.gdoc',
#  '15. PROCEDIMIENTO REVELADO ONLINE (1).pdf',
#  'BIZUM 2 (1).pptx',
#  '20240917 Seguro de movilidad personal Zurich Klinc para MediaMarkt (1).pdf',
#  'CLIENTE NO RECONOCE LA ENTREGA V06 (1).pptx',
#  'COSTOS EXTRAS INSTALACIONES (1).pdf',
#  'Cupones MiMediamarkt (1).pdf',
#  'Argumentario Recuperación Carrito V2 3 (1).pptx',
#  'Datos completos (1).ods',
#  'Declaracion jurada no reconoce entrega (1).pdf',
#  'FRAUDES ONLINE PROCEDIMIENTO Nivel 1 (1).pdf',
#  'Cuadro procedimientos V65 Actualización 24-10-2025 (1).xlsx',
#  'Garantías&ProductosDeSuscripción 1 (1).pptx',
#  'Incidencia en Instalación VO8 CON FOM (Con Arion) NUEVO Abril 2025 (1).pptx',
#  'Incidencia en login_user My Account v2.0 (1).pdf',
#  'Manual MediaMarkt (1).pdf',
#  'Manual Consulta compra tienda v2 (1).pdf',
#  'Pedidos con demora en devolución Celeritas (1).xlsx',
# ...

# %%
import pandas as pd
df = pd.read_csv(ruta)
df
# Out:
#     Nombre  Edad       Ciudad
# 0    Alice    25   Nueva York
# 1      Bob    30  Los Angeles
# 2  Charlie    35      Chicago
# 3    Diego    28      Armenia

# %%
df["nueva columna"] = "valor"
df["nueva columna"] = [10, 20, 30, None]
df
# Out:
#     Nombre  Edad       Ciudad  nueva columna
# 0    Alice    25   Nueva York           10.0
# 1      Bob    30  Los Angeles           20.0
# 2  Charlie    35      Chicago           30.0
# 3    Diego    28      Armenia            NaN
