# %% [markdown]
# <a href="https://colab.research.google.com/github/olivocdz-cmd/Programacion1/blob/main/Quiz_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Quiz 2
# ###26 de marzo
# ###***Carlos Olivo Diaz Diaz - 2192895***

# %%
# %%writefile promedio.py
import statistics
def calcular_promedio(n1, n2, n3):
    return (n1 + n2 + n3) / 3

def mediana(n1, n2, n3):
  return statistics.median([n1, n2, n3])

def moda(n1, n2, n3):
  return statistics.mode([n1, n2, n3])
# Out:
# Overwriting promedio.py

# %%
# %%writefile pedirnotas.py
def pedir_nombre():
    return input("ingrese el nombre del estudiate: ")

def pedir_notas():
    n1 = float(input("nota 1: "))
    n2 = float(input("nota 2: "))
    n3 = float(input("nota 3: "))
    n4 = float(input("nota 4: "))
    return [n1, n2, n3, n4]
# Out:
# Writing pedirnotas.py

# %%
import pedirnotas
pedirnotas.pedir_nombre()
# Out:
# ingrese el nombre del estudiate: Carlos Diaz
# 'Carlos Diaz'

# %%
notas = pedirnotas.pedir_notas()
# Out:
# nota 1: 4.5
# nota 2: 5.6
# nota 3: 5.1
# nota 4: 5.2

# %%
notas
# Out:
# [4.5, 5.6, 5.1, 5.2]

# %%
promedio_notas = sum(notas) / len(notas)
print(f"El promedio de las notas es: {promedio_notas}")
# Out:
# El promedio de las notas es: 5.1

# %%
import statistics

mediana_notas = statistics.median(notas)
print(f"La mediana de las notas es: {mediana_notas}")
# Out:
# La mediana de las notas es: 5.15

# %%
import promedio
import importlib
importlib.reload(promedio)

moda_notas = promedio.moda(notas[0], notas[1], notas[2])
print(f"La moda de las notas es: {moda_notas}")
# Out:
# La moda de las notas es: 4.5

# %%
if promedio_notas >= 3.0:
    print("El estudiante aprobó.")
else:
    print("El estudiante reprobó.")
# Out:
# El estudiante aprobó.
