# %% [markdown]
# <a href="https://colab.research.google.com/github/olivocdz-cmd/Programacion1/blob/main/Ejercicio%201.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **Ejercicio 1**

# %%
def validar_float(mensaje):
    while True:
      entrada = input(mensaje)
      try:
          return float(entrada)
      except ValueError:
          print("Error: por favor ingrese un numero valido \n")

def suma(z1, z2):
    resultado = z1 + z2
    return resultado

def multiplicacion(z1, z2):
    resultado = z1 * z2
    return resultado

def raiz_n(z, n):
    resultado = z ** (1/n)
    return resultado

def pedir_complejo():
    print("Ingreso de número complejo")
    real = validar_float("Ingrese la parte real: ")
    imaginario = validar_float("Ingrese la parte imaginaria: ")
    return complex(real, imaginario)

def menu():
    while True:
      print("MENU DE OPCIONES")
      print("1. Sumar numeros complejos")
      print("2. Multiplicar numeros complejos")
      print("3. Raiz n-esima de un numero complejo")
      print("4. Salir \n")

      opcion = input("Ingrese una opción: ")

      if opcion == "1":
          z1 = pedir_complejo()
          z2 = pedir_complejo()
          r = suma(z1, z2)
          print(f"\n> Resultado de la suma es: {r} \n")
      elif opcion == "2":
          z1 = pedir_complejo()
          z2 = pedir_complejo()
          r = multiplicacion(z1, z2)
          print(f"\n> Resultado de la multiplicacion es: {r} \n")

      elif opcion == "3":
          z = pedir_complejo()
          n = validar_float("Ingrese el valor de n (indice de la raiz): ")
          if n == 0:
            print("Error: el valor de n no puede ser 0 \n")
          else:
            r = raiz_n(z, n)
            print(f"\n> Resultado de la raiz n-esima es: {r} \n")

      elif opcion == "4":
          print("Saliendo del programa... ¡Adios!")
          break

      else:
          print("Opción no valida. Por favor, intente de nuevo.\n")

if __name__ == "__main__":
  menu()
# Out:
# MENU DE OPCIONES
# 1. Sumar numeros complejos
# 2. Multiplicar numeros complejos
# 3. Raiz n-esima de un numero complejo
# 4. Salir
